# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class_dir = '/Users/Bella/Desktop/info-3600/'

# Load psychiatric_diagnosis_processed.csv
df_dx = pd.read_csv(class_dir + 'psychiatric_diagnosis_processed.csv')

# Load heart rate data
df_hr = pd.read_csv(class_dir + 'cvd_y_fitb_act_d.csv')

# %%
# Rename df_dx columns for plotting aesthetics
df_dx['eventname'] = df_dx['eventname'].str.replace('_year_follow_up_y_arm_1', '-year follow-up')
df_dx['eventname'] = df_dx['eventname'].str.replace('baseline_year_1_arm_1', 'baseline')
df_dx.rename(columns=lambda x: x.replace('parent_report_', ''), inplace=True)

# %%
# Melt the dataframe to make diagnoses long-form
df_dx_melted = df_dx.melt(id_vars=['src_subject_id', 'eventname'], 
                    value_vars=[
                        'si_dx', 'sa_dx', 'mood_dx',
                        'psychotic_dx', 'anxiety_dx', 'elimination_dx',
                        'eating_dx', 'adhd_dx', 'autism_dx',
                        'disruptive_dx', 'tic_dx', 'sud_dx',
                        'ptsd_dx', 'sleep_dx', 'homicide_dx'
                    ], 
                    var_name='diagnosis', value_name='diagnosis_value')

# Group by eventname and diagnosis to get counts
diagnosis_counts = df_dx_melted.groupby(['eventname', 'diagnosis', 'diagnosis_value']).size().reset_index(name='count')

# Filter for diagnosis_value == 1 (subjects with diagnosis)
diagnosis_counts_yes = diagnosis_counts[diagnosis_counts['diagnosis_value'] == 1]

# Plotting
event_order = ['baseline'] + [event for event in df_dx['eventname'].unique() if event != 'baseline']  # Order xlabels so baseline category is plotted first
plt.figure(figsize=(14, 8))
sns.barplot(data=diagnosis_counts_yes, x='eventname', y='count', hue='diagnosis', order=event_order)
plt.title('Number of Subjects with Dx at Each Time Point')
plt.xlabel('Follow-Up Time Point')
plt.ylabel('Count')
plt.legend(title='Diagnosis', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Greatest number of point at baseline and 2-year follow-up. Most common dx is anxiety, followed by autism

# %%
df_hr = df_hr.drop('eventname', axis=1)
df_hr
# Out:
#         src_subject_id cvd_fit_ss_protocol_startdate  \
# 0     NDAR_INV010ZM3H9                    03/08/2020
# 1     NDAR_INV010ZM3H9                    03/08/2020
# 2     NDAR_INV010ZM3H9                    03/08/2020
# 3     NDAR_INV010ZM3H9                    03/08/2020
# 4     NDAR_INV010ZM3H9                    03/08/2020
# ...                ...                           ...
# 9234  NDAR_INVZ4DPYEX3                    03/14/2020
# 9235  NDAR_INVZ4DPYEX3                    03/14/2020
# 9236  NDAR_INVZ4DPYEX3                    03/14/2020
# 9237  NDAR_INVZ4DPYEX3                    03/14/2020
# 9238  NDAR_INVZ4DPYEX3                    03/14/2020
#
#       cvd_fit_ss_protocol_wear cvd_fit_ss_wear_date  \
# 0                            1           03/21/2020
# 1                            1           03/22/2020
# 2                            1           03/23/2020
# 3                            1           03/24/2020
# 4                            1           03/25/2020
# ...                        ...                  ...
# 9234                         0           05/24/2020
# 9235                         0           05/25/2020
# 9236                         0           05/28/2020
# 9237                         0           05/29/2020
# 9238                         0           05/30/2020
#
#       cvd_fit_ss_day_total_steps_no_el  cvd_fit_ss_day_min  \
# 0                              16713.0                 969
# 1                              13021.0                 940
# 2                               9170.0                 800
# 3                              12279.0                 854
# 4                               8427.0                 781
# ...                                ...                 ...
# 9234                            3988.0                 785
# 9235                             102.0                  35
# 9236                            4447.0                 691
# 9237                            1435.0                 585
# 9238                            7872.0                 774
#
#       cvd_fit_ss_night_min  cvd_fit_ss_sleep_min  \
# 0                      457                 364.0
# 1                      407                 653.0
# 2                      637                 516.0
# 3                      548                 662.0
# 4                      656                   NaN
# ...                    ...                   ...
# 9234                   610                   NaN
# 9235                     0                   NaN
# 9236                     0                 576.0
# 9237                   575                 471.0
# 9238                   470                   NaN
#
#       cvd_fit_ss_30_second_data_existed  cvd_fit_ss_excl_day_min  ...  \
# 0                                     1                        0  ...
# 1                                     1                       79  ...
# 2                                     1                        0  ...
# 3                                     1                        2  ...
# 4                                     0                        0  ...
# ...                                 ...                      ...  ...
# 9234                                  0                       35  ...
# 9235                                  0                     1405  ...
# 9236                                  1                      749  ...
# 9237                                  1                      280  ...
# 9238                                  0                        5  ...
#
#       cvd_fit_ss_fitbit_fairlyactivemin  cvd_fit_ss_fitbit_veryactivemin  \
# 0                                    73                               12
# 1                                    59                                2
# 2                                     8                                0
# 3                                    58                                1
# 4                                     0                                0
# ...                                 ...                              ...
# 9234                                  7                                1
# 9235                                  0                                0
# 9236                                  0                                0
# 9237                                  0                                0
# 9238                                  0                                0
#
#       cvd_fit_ss_fitbit_restingheartrate  cvd_fit_ss_mstep_lt_80_dailystep  \
# 0                                   63.0                                 0
# 1                                   62.0                                 0
# 2                                   62.0                                 0
# 3                                   63.0                                 0
# 4                                   63.0                                 0
# ...                                  ...                               ...
# 9234                                72.0                                 0
# 9235                                 NaN                                 1
# 9236                                73.0                                 0
# 9237                                73.0                                 0
# 9238                                72.0                                 0
#
#       cvd_fit_ss_dayt_total_steps  cvd_fit_ss_dayt_ave_met_value  \
# 0                         16505.0                           2.66
# 1                         13014.0                           2.46
# 2                          8937.0                           2.34
# 3                         12133.0                           2.33
# 4                          8226.0                           2.17
# ...                           ...                            ...
# 9234                       3980.0                           1.43
# 9235                        102.0                           1.37
# 9236                       4447.0                           1.62
# 9237                       1422.0                           1.27
# 9238                       7854.0                           1.86
#
#       cvd_fit_ss_dayt_sedentary_min  cvd_fit_ss_dayt_light_active_min  \
# 0                               413                               471
# 1                               427                               452
# 2                               364                               428
# 3                               428                               367
# 4                               392                               389
# ...                             ...                               ...
# 9234                            645                               132
# 9235                             29                                 6
# 9236                            480                               211
# 9237                            507                                78
# 9238                            478                               296
#
#       cvd_fit_ss_dayt_farily_active_min  cvd_fit_ss_dayt_very_active_min
# 0                                    73                               12
# 1                                    59                                2
# 2                                     8                                0
# 3                                    58                                1
# 4                                     0                                0
# ...                                 ...                              ...
# 9234                                  7                                1
# 9235                                  0                                0
# 9236                                  0                                0
# 9237                                  0                                0
# 9238                                  0                                0
#
# [9239 rows x 47 columns]

# %%
# Verify number of subjects in HR data
# Each subject has a variable number of entries (one row per day of Fitbit wear)
print(f'Number of subjects in HR data: {df_hr['src_subject_id'].nunique()}, Total number of observations: {df_hr['src_subject_id'].count()}')
# Out:
# Number of subjects in HR data: 118, Total number of observations: 9239

# %%
# Resting heart rate could be an interesting dependent variable to explore
df_hr['cvd_fit_ss_fitbit_restingheartrate'].count()
# Out:
# 8347

# %%
# Filter df_dx to include only subjects found in df_hr
# Check that # of subjects in filtered dataset matches # in HR dataset
df_dx_subset = df_dx[df_dx['src_subject_id'].isin(df_hr['src_subject_id'])]
print(f'Number of subjects in filtered dataset: {df_dx_subset['src_subject_id'].nunique()}, Total number of observations: {len(df_dx_subset)}')
# Out:
# Number of subjects in filtered dataset: 118, Total number of observations: 481

# %%
df_dx_subset
# Out:
#          src_subject_id         eventname  si_dx  sa_dx  mood_dx  \
# 14     NDAR_INV010ZM3H9          baseline      0      0        0
# 129    NDAR_INV0AAKGYA2          baseline      0      0        0
# 137    NDAR_INV0AZFZ65C          baseline      0      0        0
# 219    NDAR_INV0HJGCR32          baseline      0      0        1
# 322    NDAR_INV0UEA3Z9E          baseline      0      0        0
# ...                 ...               ...    ...    ...      ...
# 45266  NDAR_INV8MHLZCL8  4-year follow-up      0      0        0
# 45417  NDAR_INV9PTH3VTR  4-year follow-up      0      0        0
# 45900  NDAR_INVD176PR5Y  4-year follow-up      1      1        1
# 45971  NDAR_INVDGVADKJA  4-year follow-up      0      0        0
# 48019  NDAR_INVV82L1HKC  4-year follow-up      0      0        0
#
#        psychotic_dx  anxiety_dx  elimination_dx  eating_dx  adhd_dx  \
# 14                0           0               0          0        0
# 129               0           0               0          0        1
# 137               0           0               0          0        0
# 219               0           1               0          0        0
# 322               0           1               0          0        0
# ...             ...         ...             ...        ...      ...
# 45266             0           1               0          0        0
# 45417             0           0               0          0        0
# 45900             0           1               0          0        0
# 45971             0           0               0          0        0
# 48019             0           0               0          0        0
#
#        autism_dx  disruptive_dx  tic_dx  sud_dx  ptsd_dx  sleep_dx  \
# 14             1              0       0       0        0         0
# 129            0              0       0       0        0         0
# 137            0              0       0       0        0         0
# 219            1              0       0       0        1         1
# 322            0              0       0       0        0         0
# ...          ...            ...     ...     ...      ...       ...
# 45266          0              0       0       0        1         0
# 45417          0              0       0       0        0         0
# 45900          0              0       0       0        1         0
# 45971          0              0       0       0        0         0
# 48019          0              0       0       0        0         0
#
#        homicide_dx
# 14               0
# 129              0
# 137              0
# 219              0
# 322              0
# ...            ...
# 45266            0
# 45417            0
# 45900            0
# 45971            0
# 48019            0
#
# [481 rows x 17 columns]

# %%
# Plot filtered dataset
df_dx_subset_melted = df_dx_subset.melt(id_vars=['src_subject_id', 'eventname'], 
                    value_vars=[
                        'si_dx', 'sa_dx', 'mood_dx',
                        'psychotic_dx', 'anxiety_dx', 'elimination_dx',
                        'eating_dx', 'adhd_dx', 'autism_dx',
                        'disruptive_dx', 'tic_dx', 'sud_dx',
                        'ptsd_dx', 'sleep_dx', 'homicide_dx'
                    ], 
                    var_name='diagnosis', value_name='diagnosis_value')
diagnosis_counts = df_dx_subset_melted.groupby(['eventname', 'diagnosis', 'diagnosis_value']).size().reset_index(name='count')
diagnosis_counts_yes = diagnosis_counts[diagnosis_counts['diagnosis_value'] == 1]

# Plot with specified xlabel order, fig size
event_order = ['baseline'] + [event for event in df_dx['eventname'].unique() if event != 'baseline']
plt.figure(figsize=(14, 8))
sns.barplot(data=diagnosis_counts_yes, x='eventname', y='count', hue='diagnosis', order=event_order)
plt.title('Number of Subjects Surveyed at Each Time Point')
plt.xlabel('Follow-Up Time Point')
plt.ylabel('Count')
plt.legend(title='Diagnosis', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
#plt.show()
plt.savefig(f'{class_dir}/diagnosis_counts_by_subject.png', dpi=200)
